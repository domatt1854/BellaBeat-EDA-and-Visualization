# %% [markdown]
# ### Importing Packages

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from bokeh.plotting import figure, show

# %% [markdown]
# ### Reading in Data

# %%
file_path = 'Fitabase Data 4.12.16-5.12.16/'
df_daily = pd.read_csv(file_path + 'dailyActivity_merged.csv')
df_daily_orig = df_daily
df_daily.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %% [markdown]
# ### Data Preprocessing of Daily Activity

# %%
df_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
#  13  SedentaryMinutes          940 non-null    int64
#  14  Calories                  940 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 110.3+ KB

# %% [markdown]
# ##### A quick check on our data tells us that no values are null in the dataset

# %%
df_daily.isnull().values.any()
# Out:
# False

# %% [markdown]
# ##### Converting ActivityDate to a datetime column

# %%
df_daily['ActivityDate'] = pd.to_datetime(df_daily['ActivityDate'])
df_daily['ActivityDate'].head()
# Out:
# 0   2016-04-12
# 1   2016-04-13
# 2   2016-04-14
# 3   2016-04-15
# 4   2016-04-16
# Name: ActivityDate, dtype: datetime64[ns]

# %% [markdown]
# # EDA of Daily Activity

# %% [markdown]
# ##### Our distributions of both Total Distance and Total Steps are Right Skewed.
#
# ##### Many days are spent walking less than one thousand steps or a mile

# %%
fig, ax = plt.subplots(1,2, figsize = (14,6))

sns.histplot(data = df_daily['TotalDistance'], ax = ax[0])

sns.histplot(data = df_daily['TotalSteps'], ax = ax[1])
# Out:
# <AxesSubplot:xlabel='TotalSteps', ylabel='Count'>

# %%
scatter_plots = sns.PairGrid(df_daily[['TotalSteps', 'TotalDistance', 'Calories','SedentaryMinutes','VeryActiveMinutes']])
scatter_plots.map(plt.scatter)

# %% [markdown]
# #### Findings from PairPlot
#
# * Calories has a high positive correlation with Steps, Distance, and Very Active Minutes.
# * Sedentary Minutes has a negative correlation with Total Steps, Very Active Distance, and Total Distance

# %% [markdown]
# ##### Taking a Closer Look at Total Steps and Total Distance vs Calories, they are very similar

# %%
df_steps = df_daily[df_daily['TotalSteps'] != 0]
df_distance = df_daily[df_daily['TotalDistance'] != 0]

fig, ax = plt.subplots(1,2,figsize=(14,6))

ax_steps = sns.regplot(data = df_daily, x = 'TotalSteps', y = 'Calories', ax = ax[0])

ax_distance = sns.regplot(data = df_daily, x = 'TotalDistance', y = 'Calories', ax = ax[1])

# %% [markdown]
# #### As the month progresses, the amount of times people that track their daily activity drops

# %%
fig, ax = plt.subplots(2,1,figsize=(16, 12))


df_daily_num_logs = pd.DataFrame(df_daily['ActivityDate'].value_counts())

ax_user_count = sns.lineplot(data = df_daily_num_logs, ax = ax[0])
ax_user_count.set_ylim(0, 35)
ax_user_count.set_ylabel('Count of Activity Log')
ax_user_count.set_xlabel('Date')
ax_user_count.set_title('Count of Users that Logged Their Daily Activity')
ax_user_count.grid()

ax_mean_steps = sns.lineplot(data = df_daily.groupby('ActivityDate')['TotalSteps'].mean(), ax = ax[1])
ax_mean_steps.set_ylabel('Total Mean Steps Of All Users')
ax_mean_steps.set_xlabel('Date')
ax_mean_steps.set_title('Mean Steps of 33 Unique Users')
ax_mean_steps.grid()

plt.show()

# %% [markdown]
# ### Correlation Matrix and Correlation Heatmap

# %%
corr = df_daily.drop(columns = 'Id').corr()
corr
# Out:
#                           TotalSteps  TotalDistance  TrackerDistance  \
# TotalSteps                  1.000000       0.985369         0.984822
# TotalDistance               0.985369       1.000000         0.999505
# TrackerDistance             0.984822       0.999505         1.000000
# LoggedActivitiesDistance    0.181849       0.188332         0.162585
# VeryActiveDistance          0.740115       0.794582         0.794338
# ModeratelyActiveDistance    0.507105       0.470758         0.470277
# LightActiveDistance         0.692208       0.662002         0.661365
# SedentaryActiveDistance     0.070505       0.082389         0.074591
# VeryActiveMinutes           0.667079       0.681297         0.680816
# FairlyActiveMinutes         0.498693       0.462899         0.463154
# LightlyActiveMinutes        0.569600       0.516300         0.514713
# SedentaryMinutes           -0.327484      -0.288094        -0.289343
# Calories                    0.591568       0.644962         0.645313
#
#                           LoggedActivitiesDistance  VeryActiveDistance  \
# TotalSteps                                0.181849            0.740115
# TotalDistance                             0.188332            0.794582
# TrackerDistance                           0.162585            0.794338
# LoggedActivitiesDistance                  1.000000            0.150852
# VeryActiveDistance                        0.150852            1.000000
# ModeratelyActiveDistance                  0.076527            0.192986
# LightActiveDistance                       0.138302            0.157669
# SedentaryActiveDistance                   0.154996            0.046117
# VeryActiveMinutes                         0.234443            0.826681
# FairlyActiveMinutes                       0.053860            0.211730
# LightlyActiveMinutes                      0.102135            0.059845
# SedentaryMinutes                         -0.046999           -0.061754
# Calories                                  0.207595            0.491959
#
#                           ModeratelyActiveDistance  LightActiveDistance  \
# TotalSteps                                0.507105             0.692208
# TotalDistance                             0.470758             0.662002
# TrackerDistance                           0.470277             0.661365
# LoggedActivitiesDistance                  0.076527             0.138302
# VeryActiveDistance                        0.192986             0.157669
# ModeratelyActiveDistance                  1.000000             0.237847
# LightActiveDistance                       0.237847             1.000000
# SedentaryActiveDistance                   0.005793             0.099503
# VeryActiveMinutes                         0.225464             0.154966
# FairlyActiveMinutes                       0.946934             0.220129
# LightlyActiveMinutes                      0.162092             0.885697
# SedentaryMinutes                         -0.221436            -0.413552
# Calories                                  0.216790             0.466917
#
#                           SedentaryActiveDistance  VeryActiveMinutes  \
# TotalSteps                               0.070505           0.667079
# TotalDistance                            0.082389           0.681297
# TrackerDistance                          0.074591           0.680816
# LoggedActivitiesDistance                 0.154996           0.234443
# VeryActiveDistance                       0.046117           0.826681
# ModeratelyActiveDistance                 0.005793           0.225464
# LightActiveDistance                      0.099503           0.154966
# SedentaryActiveDistance                  1.000000           0.008258
# VeryActiveMinutes                        0.008258           1.000000
# FairlyActiveMinutes                     -0.022361           0.312420
# LightlyActiveMinutes                     0.124185           0.051926
# SedentaryMinutes                         0.035475          -0.164671
# Calories                                 0.043652           0.615838
#
#                           FairlyActiveMinutes  LightlyActiveMinutes  \
# TotalSteps                           0.498693              0.569600
# TotalDistance                        0.462899              0.516300
# TrackerDistance                      0.463154              0.514713
# LoggedActivitiesDistance             0.053860              0.102135
# VeryActiveDistance                   0.211730              0.059845
# ModeratelyActiveDistance             0.946934              0.162092
# LightActiveDistance                  0.220129              0.885697
# SedentaryActiveDistance             -0.022361              0.124185
# VeryActiveMinutes                    0.312420              0.051926
# FairlyActiveMinutes                  1.000000              0.148820
# LightlyActiveMinutes                 0.148820              1.000000
# SedentaryMinutes                    -0.237446             -0.437104
# Calories                             0.297623              0.286718
#
#                           SedentaryMinutes  Calories
# TotalSteps                       -0.327484  0.591568
# TotalDistance                    -0.288094  0.644962
# TrackerDistance                  -0.289343  0.645313
# LoggedActivitiesDistance         -0.046999  0.207595
# VeryActiveDistance               -0.061754  0.491959
# ModeratelyActiveDistance         -0.221436  0.216790
# LightActiveDistance              -0.413552  0.466917
# SedentaryActiveDistance           0.035475  0.043652
# VeryActiveMinutes                -0.164671  0.615838
# FairlyActiveMinutes              -0.237446  0.297623
# LightlyActiveMinutes             -0.437104  0.286718
# SedentaryMinutes                  1.000000 -0.106973
# Calories                         -0.106973  1.000000

# %% [markdown]
# ##### The total distance someone travels has the highest correlation with calories burnt

# %%
# Highest correlated fields with calories
corr.iloc[-1].sort_values(ascending = False)
# Out:
# Calories                    1.000000
# TrackerDistance             0.645313
# TotalDistance               0.644962
# VeryActiveMinutes           0.615838
# TotalSteps                  0.591568
# VeryActiveDistance          0.491959
# LightActiveDistance         0.466917
# FairlyActiveMinutes         0.297623
# LightlyActiveMinutes        0.286718
# ModeratelyActiveDistance    0.216790
# LoggedActivitiesDistance    0.207595
# SedentaryActiveDistance     0.043652
# SedentaryMinutes           -0.106973
# Name: Calories, dtype: float64

# %% [markdown]
# ##### Heatmap of daily activities. Values lighter and closer to 1 are positively correlated, while those that negative values are negatively correlated

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df_daily.drop(columns = 'Id').corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Regressionplot of Distance and Calories

# %%
fig, ax = plt.subplots(2,2,figsize=(16, 10))

sns.regplot(ax = ax[0,0], data = df_daily, x='VeryActiveDistance', y ='Calories')

sns.regplot(ax = ax[0,1],data = df_daily, x='ModeratelyActiveDistance', y ='Calories')

sns.regplot(ax = ax[1,0],data = df_daily, x='LightActiveDistance', y ='Calories')

sns.regplot(ax = ax[1,1],data = df_daily, x='SedentaryActiveDistance', y ='Calories')
# Out:
# <AxesSubplot:xlabel='SedentaryActiveDistance', ylabel='Calories'>

# %% [markdown]
# #### Shown more in magnitude, minutes spent sedentary have a negative correlation with calories burned

# %%
# Regressionplot of Minutes and Calories
fig, ax = plt.subplots(2,2,figsize=(16, 10))

sns.regplot(ax = ax[0,0], data = df_daily, x='VeryActiveMinutes', y ='Calories', scatter_kws={'alpha':0.5})

sns.regplot(ax = ax[0,1],data = df_daily, x='FairlyActiveMinutes', y ='Calories',scatter_kws={'alpha':0.5})

sns.regplot(ax = ax[1,0],data = df_daily, x='LightlyActiveMinutes', y ='Calories',scatter_kws={'alpha':0.5})

sns.regplot(ax = ax[1,1],data = df_daily, x='SedentaryMinutes', y ='Calories',scatter_kws={'alpha':0.5})
# Out:
# <AxesSubplot:xlabel='SedentaryMinutes', ylabel='Calories'>

# %% [markdown]
# ## Breaking Down Metrics by Weekday

# %%
print("The data is recorded from:",df_daily['ActivityDate'].min(), "to", df_daily['ActivityDate'].max())
# Out:
# The data is recorded from: 2016-04-12 00:00:00 to 2016-05-12 00:00:00

# %% [markdown]
# 2016-04-12 was a tuesday, and 2016-05-12 was a wednesday. Visualizaing the weekdays and the amount of activity logs on that day show that people are least like to wear their fitbit on Monday.
#
# The day people are most likely to wear a fitbit is on Tuesday, which decreases steadily into next week's Monday

# %%
df_daily['weekday'] = df_daily['ActivityDate'].dt.weekday

df_daily['weekday'].value_counts().sort_index(ascending=True).plot(kind='bar')

# Monday = 0
# Sunday = 6
# Out:
# <AxesSubplot:>

# %%
print("Range of our User's Average Burned Calories:",df_daily.groupby('Id')['Calories'].mean().min().astype(int),
      "-", df_daily.groupby('Id')['Calories'].mean().max().astype(int))
# Out:
# Range of our User's Average Burned Calories: 1483 - 3436

# %%
df_daily.groupby('Id')['Calories'].mean().sort_values(ascending=True).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Id'>

# %% [markdown]
# ## Weekday vs Activity Types

# %% [markdown]
# #### On a top level view, there isn't a large difference between the days people do activies

# %%
df_groupby_sedentary = pd.DataFrame(df_daily.groupby('weekday')['SedentaryMinutes'].mean())
df_groupby_lightly = pd.DataFrame(df_daily.groupby('weekday')['LightlyActiveMinutes'].mean())
df_groupby_fairly = pd.DataFrame(df_daily.groupby('weekday')['FairlyActiveMinutes'].mean())
df_gropuby_very_active = pd.DataFrame(df_daily.groupby('weekday')['VeryActiveMinutes'].mean())

# %%
#Plotting out the activity minute means across weekdays,
#with monday = 0, Sunday = 6

fig, ax = plt.subplots(2,2,figsize=(16, 10))

sns.barplot(ax = ax[0,0], data = df_groupby_sedentary, x = df_groupby_sedentary.index, y = 'SedentaryMinutes')

sns.barplot(ax = ax[0,1], data = df_groupby_sedentary, x = df_groupby_sedentary.index, y = 'SedentaryMinutes')

sns.barplot(ax = ax[1,0], data = df_groupby_sedentary, x = df_groupby_sedentary.index, y = 'SedentaryMinutes')

sns.barplot(ax = ax[1,1], data = df_groupby_sedentary, x = df_groupby_sedentary.index, y = 'SedentaryMinutes')
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='SedentaryMinutes'>

# %% [markdown]
# ### There are about 1440 minutes in a day, it seems that there are some days where people are completely sedentary. There also seems to be a separation around the 900 minute time. This could be the split between people who wear their fit bit to sleep and those who do not

# %%
plt.figure(figsize=(18,12))
ax_strip_plot = sns.stripplot(x="weekday", y="SedentaryMinutes", data=df_daily)

#This line marks 24 hours
ax_strip_plot.axhline(1440)

# %%
plt.figure(figsize=(18,6))
sns.boxplot(x="weekday", y="SedentaryMinutes", data=df_daily)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='SedentaryMinutes'>

# %%
plt.figure(figsize=(18,6))
sns.boxplot(x="weekday", y="LightlyActiveMinutes", data=df_daily)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='LightlyActiveMinutes'>

# %%
plt.figure(figsize=(18,6))
sns.boxplot(x="weekday", y="FairlyActiveMinutes", data=df_daily)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='FairlyActiveMinutes'>

# %%
plt.figure(figsize=(18,6))
sns.boxplot(x="weekday", y="VeryActiveMinutes", data=df_daily)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='VeryActiveMinutes'>

# %% [markdown]
# ### Calories Burnt by Hour

# %%
df_minutes = pd.read_csv(file_path + 'minuteCaloriesWide_merged.csv')

# %%
df_minutes['ActivityHour'] = pd.to_datetime(df_minutes['ActivityHour'])

# %%
df_minutes_date_groupby = df_minutes.drop(columns = ['Id']).groupby('ActivityHour').mean()
df_minutes_date_groupby
# Out:
#                      Calories00  Calories01  Calories02  Calories03  \
# ActivityHour
# 2016-04-13 00:00:00    1.218644    1.233753    1.125290    1.132358
# 2016-04-13 01:00:00    1.117827    1.119095    1.158911    1.107733
# 2016-04-13 02:00:00    1.107733    1.113309    1.111216    1.116798
# 2016-04-13 03:00:00    1.113309    1.107733    1.113309    1.113309
# 2016-04-13 04:00:00    1.166808    1.127425    1.113196    1.174147
# ...                         ...         ...         ...         ...
# 2016-05-13 04:00:00    1.095221    1.103894    1.103894    1.125344
# 2016-05-13 05:00:00    2.022346    2.022346    2.022346    2.022346
# 2016-05-13 06:00:00    1.097530    1.105281    1.108990    1.097530
# 2016-05-13 07:00:00    1.466925    1.406075    1.436500    1.272058
# 2016-05-13 08:00:00    1.020054    1.014802    1.035556    1.429882
#
#                      Calories04  Calories05  Calories06  Calories07  \
# ActivityHour
# 2016-04-13 00:00:00    1.229974    1.226176    1.202129    1.161294
# 2016-04-13 01:00:00    1.119573    1.120990    1.125730    1.180048
# 2016-04-13 02:00:00    1.183701    1.155071    1.113315    1.110465
# 2016-04-13 03:00:00    1.107733    1.107733    1.107733    1.107733
# 2016-04-13 04:00:00    1.119594    1.116159    1.116041    1.196945
# ...                         ...         ...         ...         ...
# 2016-05-13 04:00:00    1.251320    1.320697    1.286009    1.109837
# 2016-05-13 05:00:00    2.022346    2.029848    2.022346    2.022346
# 2016-05-13 06:00:00    1.097530    1.097530    1.097530    1.097530
# 2016-05-13 07:00:00    1.305316    1.421673    1.479805    1.553575
# 2016-05-13 08:00:00    1.237082    1.388374    1.035556    1.268086
#
#                      Calories08  Calories09  ...  Calories50  Calories51  \
# ActivityHour                                 ...
# 2016-04-13 00:00:00    1.121629    1.207545  ...    1.155144    1.205178
# 2016-04-13 01:00:00    1.194080    1.118615  ...    1.172756    1.201862
# 2016-04-13 02:00:00    1.115928    1.118772  ...    1.107733    1.107733
# 2016-04-13 03:00:00    1.107733    1.107733  ...    1.113196    1.113309
# 2016-04-13 04:00:00    1.224272    1.166267  ...    1.112075    1.107733
# ...                         ...         ...  ...         ...         ...
# 2016-05-13 04:00:00    1.095221    1.095221  ...    1.121663    1.101651
# 2016-05-13 05:00:00    2.022346    2.022346  ...    2.045693    2.022346
# 2016-05-13 06:00:00    1.097530    1.127560  ...    1.576834    1.485073
# 2016-05-13 07:00:00    1.505438    1.283634  ...    1.109273    1.425313
# 2016-05-13 08:00:00    1.299090    1.289856  ...    1.268086    1.330094
#
#                      Calories52  Calories53  Calories54  Calories55  \
# ActivityHour
# 2016-04-13 00:00:00    1.268504    1.221072    1.221818    1.222769
# 2016-04-13 01:00:00    1.169500    1.113309    1.111287    1.114841
# 2016-04-13 02:00:00    1.107733    1.115512    1.111608    1.117651
# 2016-04-13 03:00:00    1.109863    1.107733    1.113309    1.110509
# 2016-04-13 04:00:00    1.111216    1.112075    1.117651    1.182773
# ...                         ...         ...         ...         ...
# 2016-05-13 04:00:00    1.095221    1.108081    1.095221    1.101651
# 2016-05-13 05:00:00    2.022346    2.022346    2.022346    1.169305
# 2016-05-13 06:00:00    1.586646    1.808236    1.988416    1.303588
# 2016-05-13 07:00:00    1.303841    1.574519    1.403129    1.352808
# 2016-05-13 08:00:00    1.299090    1.035556    1.035556    1.035556
#
#                      Calories56  Calories57  Calories58  Calories59
# ActivityHour
# 2016-04-13 00:00:00    1.180155    1.116190    1.136600    1.131893
# 2016-04-13 01:00:00    1.107733    1.107733    1.113309    1.116159
# 2016-04-13 02:00:00    1.161973    1.209205    1.227652    1.164408
# 2016-04-13 03:00:00    1.173295    1.152227    1.121080    1.157802
# 2016-04-13 04:00:00    1.107733    1.107733    1.116223    1.107733
# ...                         ...         ...         ...         ...
# 2016-05-13 04:00:00    1.095221    1.100758    1.095221    1.095221
# 2016-05-13 05:00:00    1.145958    1.145958    1.145958    1.169305
# 2016-05-13 06:00:00    1.171821    1.373021    1.476071    1.395300
# 2016-05-13 07:00:00    1.677660    1.662865    1.718498    1.326403
# 2016-05-13 08:00:00    1.035556    1.237082    1.035556    1.388374
#
# [729 rows x 60 columns]

# %%
#There are 

df_minutes_date_groupby_mean = df_minutes_date_groupby.sum(axis = 1) / len(df_minutes_date_groupby.columns)

plt.figure(figsize= (22,8))
df_minutes_date_groupby_mean.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='ActivityHour'>

# %%
df_minutes['ActivityHourExtractedhour'] = df_minutes['ActivityHour'].dt.hour

groupby_minutes_aggregate = df_minutes.drop(columns = ['Id', 'ActivityHour']).groupby('ActivityHourExtractedhour').mean()
groupby_minutes_aggregate
# Out:
#                            Calories00  Calories01  Calories02  Calories03  \
# ActivityHourExtractedhour
# 0                            1.272130    1.242750    1.234776    1.252087
# 1                            1.167493    1.179307    1.167544    1.178374
# 2                            1.166652    1.172222    1.172107    1.173308
# 3                            1.118741    1.121119    1.125410    1.125617
# 4                            1.130990    1.136524    1.146650    1.148108
# 5                            1.306789    1.325882    1.342490    1.368625
# 6                            1.310809    1.341811    1.358283    1.355684
# 7                            1.590122    1.603768    1.570924    1.535712
# 8                            1.658080    1.638651    1.683891    1.680618
# 9                            1.743946    1.709517    1.702112    1.695620
# 10                           1.810891    1.789748    1.828711    1.841552
# 11                           1.859420    1.834873    1.831376    1.821000
# 12                           1.890217    1.998053    1.955261    1.960301
# 13                           1.869473    1.841689    1.897964    1.953952
# 14                           2.027879    1.985894    2.043714    2.000424
# 15                           1.779618    1.810447    1.841748    1.857890
# 16                           1.832845    1.910983    1.923708    1.884387
# 17                           1.933015    1.939856    1.988188    1.983668
# 18                           2.027355    2.025974    2.028506    2.059395
# 19                           2.106802    2.094527    2.120996    2.074912
# 20                           1.850925    1.818880    1.819769    1.817315
# 21                           1.603847    1.633770    1.656551    1.610896
# 22                           1.614630    1.600115    1.572647    1.556673
# 23                           1.338039    1.344621    1.364064    1.384411
#
#                            Calories04  Calories05  Calories06  Calories07  \
# ActivityHourExtractedhour
# 0                            1.257591    1.236933    1.241350    1.230408
# 1                            1.177072    1.177036    1.188671    1.193555
# 2                            1.184725    1.171136    1.187758    1.176304
# 3                            1.119385    1.117195    1.114505    1.119397
# 4                            1.144750    1.139603    1.135959    1.136847
# 5                            1.368936    1.357319    1.341491    1.336733
# 6                            1.352559    1.332244    1.326764    1.368738
# 7                            1.536827    1.535931    1.518944    1.523773
# 8                            1.683169    1.675028    1.671742    1.719172
# 9                            1.727039    1.735907    1.733548    1.746381
# 10                           1.821462    1.839312    1.866180    1.801509
# 11                           1.872364    1.882266    1.868138    1.810666
# 12                           2.031723    2.002625    2.014125    1.907797
# 13                           1.910377    1.930218    1.962954    1.949184
# 14                           1.963637    1.953268    2.007375    1.985598
# 15                           1.834429    1.836898    1.863521    1.802236
# 16                           1.915362    1.846442    1.863510    1.881422
# 17                           2.001263    1.997306    1.963082    1.957870
# 18                           2.022813    2.092784    2.036077    2.061342
# 19                           2.129536    2.210167    2.238476    2.210337
# 20                           1.780572    1.769680    1.812708    1.781326
# 21                           1.630908    1.604215    1.584549    1.607946
# 22                           1.563091    1.603427    1.559612    1.541918
# 23                           1.350396    1.342500    1.326670    1.325514
#
#                            Calories08  Calories09  ...  Calories50  \
# ActivityHourExtractedhour                          ...
# 0                            1.210740    1.210246  ...    1.184713
# 1                            1.168190    1.165022  ...    1.141204
# 2                            1.177527    1.152872  ...    1.135476
# 3                            1.127144    1.121305  ...    1.114108
# 4                            1.140819    1.129201  ...    1.123138
# 5                            1.335032    1.339467  ...    1.441204
# 6                            1.355445    1.377366  ...    1.540867
# 7                            1.554180    1.530082  ...    1.590413
# 8                            1.665201    1.642108  ...    1.755901
# 9                            1.777597    1.777410  ...    1.805944
# 10                           1.854276    1.794112  ...    1.820060
# 11                           1.813214    1.830265  ...    1.827479
# 12                           1.889232    1.892269  ...    1.893909
# 13                           1.914674    1.975473  ...    2.014268
# 14                           2.004381    1.985713  ...    1.855339
# 15                           1.798439    1.841226  ...    1.788058
# 16                           1.833578    1.798495  ...    1.954843
# 17                           1.905765    1.949689  ...    2.157800
# 18                           2.058674    2.009555  ...    2.060921
# 19                           2.153080    2.141303  ...    1.864779
# 20                           1.773085    1.796126  ...    1.693789
# 21                           1.635793    1.661032  ...    1.610963
# 22                           1.554130    1.558583  ...    1.378456
# 23                           1.335477    1.331669  ...    1.275385
#
#                            Calories51  Calories52  Calories53  Calories54  \
# ActivityHourExtractedhour
# 0                            1.185324    1.185666    1.182778    1.173492
# 1                            1.158923    1.160141    1.159195    1.162621
# 2                            1.128225    1.140678    1.134899    1.132757
# 3                            1.120537    1.121040    1.119972    1.115406
# 4                            1.118626    1.121491    1.122391    1.123022
# 5                            1.425442    1.447441    1.448498    1.474349
# 6                            1.514522    1.529466    1.563904    1.554026
# 7                            1.593686    1.607732    1.628737    1.654499
# 8                            1.726591    1.734314    1.755483    1.748348
# 9                            1.836396    1.819697    1.790423    1.817016
# 10                           1.828315    1.832771    1.871508    1.873056
# 11                           1.789235    1.839829    1.815589    1.870161
# 12                           1.929826    1.931685    1.864767    1.839812
# 13                           1.952289    1.981431    2.013409    2.011260
# 14                           1.786425    1.811060    1.735964    1.740912
# 15                           1.800134    1.798977    1.775075    1.780513
# 16                           2.013267    2.006588    2.024914    2.042373
# 17                           2.111280    2.115997    2.122747    2.054471
# 18                           2.075447    2.098820    2.060352    2.106166
# 19                           1.856826    1.853095    1.851611    1.840398
# 20                           1.652069    1.664599    1.653835    1.657450
# 21                           1.578027    1.578434    1.597999    1.608767
# 22                           1.342186    1.321761    1.349230    1.332402
# 23                           1.263194    1.259248    1.252043    1.253789
#
#                            Calories55  Calories56  Calories57  Calories58  \
# ActivityHourExtractedhour
# 0                            1.160921    1.163776    1.168123    1.156160
# 1                            1.158598    1.164121    1.167546    1.174947
# 2                            1.140221    1.128700    1.139313    1.131744
# 3                            1.125290    1.128117    1.122065    1.122561
# 4                            1.124949    1.129785    1.123280    1.129349
# 5                            1.305058    1.279217    1.296645    1.291418
# 6                            1.542393    1.551372    1.565423    1.542784
# 7                            1.673738    1.713289    1.711423    1.708667
# 8                            1.776085    1.753359    1.744493    1.780691
# 9                            1.819411    1.801515    1.802711    1.786557
# 10                           1.884780    1.866884    1.860502    1.841541
# 11                           1.885826    1.847539    1.870048    1.846947
# 12                           1.833245    1.816836    1.861644    1.823254
# 13                           2.033799    1.997579    2.008796    2.017623
# 14                           1.755117    1.810344    1.788330    1.778968
# 15                           1.776059    1.768289    1.757298    1.742596
# 16                           1.988851    1.975102    1.969802    1.964025
# 17                           2.084043    2.061589    2.104040    2.120889
# 18                           2.100410    2.113662    2.113076    2.088465
# 19                           1.873246    1.844329    1.825968    1.837012
# 20                           1.615199    1.607974    1.613588    1.646160
# 21                           1.593027    1.574054    1.553961    1.570615
# 22                           1.329825    1.327993    1.336570    1.366435
# 23                           1.262725    1.241749    1.257256    1.270840
#
#                            Calories59
# ActivityHourExtractedhour
# 0                            1.170643
# 1                            1.175542
# 2                            1.126476
# 3                            1.124760
# 4                            1.131735
# 5                            1.300817
# 6                            1.583210
# 7                            1.682891
# 8                            1.743217
# 9                            1.784423
# 10                           1.884674
# 11                           1.892360
# 12                           1.881363
# 13                           1.981644
# 14                           1.788099
# 15                           1.809358
# 16                           1.929897
# 17                           2.040147
# 18                           2.051776
# 19                           1.842483
# 20                           1.605026
# 21                           1.536740
# 22                           1.402742
# 23                           1.278518
#
# [24 rows x 60 columns]

# %%
# Mean calories burned show that noon and evenings are the most frequent times to exercise

plt.figure(figsize= (22,8))
groupby_minutes_aggregate_mean = groupby_minutes_aggregate.sum(axis = 1) / len(groupby_minutes_aggregate.columns)

sns.lineplot(data = groupby_minutes_aggregate_mean)
plt.xticks([i for i in range(24)])
plt.show()

# %% [markdown]
# ## Quick Linear Regression on Predicting Calories

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df_daily_activities = df_daily_orig
df_daily_activities
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                1.88                      0.55
# 1                         0.0                1.57                      0.69
# 2                         0.0                2.44                      0.40
# 3                         0.0                2.14                      1.26
# 4                         0.0                2.71                      0.41
# ..                        ...                 ...                       ...
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   6.06                     0.00                 25
# 1                   4.71                     0.00                 21
# 2                   3.91                     0.00                 30
# 3                   2.83                     0.00                 29
# 4                   5.04                     0.00                 36
# ..                   ...                      ...                ...
# 935                 6.80                     0.00                 17
# 936                 6.24                     0.05                 73
# 937                 6.28                     0.00                 18
# 938                 5.89                     0.00                 88
# 939                 4.25                     0.00                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# 2                     11                   181              1218      1776
# 3                     34                   209               726      1745
# 4                     10                   221               773      1863
# ..                   ...                   ...               ...       ...
# 935                    4                   245              1174      2847
# 936                   19                   217              1131      3710
# 937                   11                   224              1187      2832
# 938                   12                   213              1127      3832
# 939                    1                   137               770      1849
#
# [940 rows x 15 columns]

# %%
df_daily_activities = df_daily_activities.drop(columns = ['Id','ActivityDate'])

# %%
X_train, X_test, y_train, y_test = train_test_split(df_daily_activities.drop(columns = ['Calories']),
                                                    df_daily_activities['Calories'], random_state = 42)

# %%
Linear_Regression = LinearRegression()

Linear_Regression.fit(X_train, y_train)

prediction = Linear_Regression.predict(X_test)

Linear_Regression.score(X_test,y_test)
# Out:
# 0.7230674925312157
